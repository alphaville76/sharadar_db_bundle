# %%
from collections import OrderedDict
import pandas as pd
import pyfolio as pf
import numpy as np
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
results = pd.read_pickle('../algo/wwws/wwws_perf.pickle')
#results = pd.read_pickle('../examples/dma_perf.pickle')

# %%
results.portfolio_value.plot()

# %%
results.positions.count()
# Out:
# 2338

# %%
np.sum([p in results.positions])
# Out:
# 0

# %%
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-afa478635f8d> in <module>
# ----> 1 returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(results)
#
# /home/costantino/zipline/lib/python3.6/site-packages/pyfolio/utils.py in extract_rets_pos_txn_from_zipline(backtest)
#     160         raise ValueError("The backtest does not have any positions.")
#     161     positions = pd.concat(raw_positions)
# --> 162     positions = pos.extract_pos(positions, backtest.ending_cash)
#     163     transactions = txn.make_transaction_frame(backtest.transactions)
#     164     if transactions.index.tzinfo is None:
#
# /home/costantino/zipline/lib/python3.6/site-packages/pyfolio/pos.py in extract_pos(positions, cash)
#     136
#     137     positions = positions.copy()
# --> 138     positions['values'] = positions.amount * positions.last_sale_price
# ...

# %%
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, round_trips=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-01-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>36</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.1%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.14</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-0.1%</td>
#     </tr>
#     <tr>
# ...
